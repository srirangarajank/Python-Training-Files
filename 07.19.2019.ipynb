# %%
#Files & exceptions
#Reading and writing files

# %%
with open('digits_file.txt') as file_object:
    contents = file_object.read()
print(contents)
#It will display the output file
# Out:
# 14314
# 32121
# 324234
# 2432
# 34
# 32

# %%
#...How to specify a path in our local system, rather than uploading the file in a jupyter notebook
with open('/usr/local/google/home/sbeluri/Downloads/students.txt') as file_object:
    contents = file_object.read()
print(contents.title())
# Out:
# Sri
# Akshay

# %%
file_path = '/usr/local/google/home/sbeluri/Downloads/students.txt'

with open(file_path) as file_object:
    contents = file_object.read()
print(contents)
# Out:
# sri
# akshay

# %%
file_path = '/usr/local/google/home/sbeluri/Downloads/students.txt'

with open(file_path) as file_object:
    contents = file_object.read()
print(contents)
# Out:
# sri
# akshay

# %%
for i in range(0,255):
    print(i)
    if i<= 255:
        print('True')
    else:
        print('False')
# Out:
# 0
# True
# 1
# True
# 2
# True
# 3
# True
# 4
# True
# 5
# True
# 6
# True
# 7
# True
# 8
# True
# 9
# True
# 10
# True
# 11
# True
# 12
# True
# 13
# True
# 14
# True
# 15
# True
# 16
# True
# 17
# True
# 18
# True
# 19
# True
# 20
# True
# 21
# True
# 22
# True
# 23
# True
# 24
# True
# 25
# True
# 26
# True
# 27
# True
# 28
# True
# 29
# True
# 30
# True
# 31
# True
# 32
# True
# 33
# True
# 34
# True
# 35
# True
# 36
# True
# 37
# True
# 38
# True
# 39
# True
# 40
# True
# 41
# True
# 42
# True
# 43
# True
# 44
# True
# 45
# True
# 46
# True
# 47
# True
# 48
# True
# 49
# True
# 50
# True
# 51
# True
# 52
# True
# 53
# True
# 54
# True
# 55
# True
# 56
# True
# 57
# True
# 58
# True
# 59
# True
# 60
# True
# 61
# True
# 62
# True
# 63
# True
# 64
# True
# 65
# True
# 66
# True
# 67
# True
# 68
# True
# 69
# True
# 70
# True
# 71
# True
# 72
# True
# 73
# True
# 74
# True
# 75
# True
# 76
# True
# 77
# True
# 78
# True
# 79
# True
# 80
# True
# 81
# True
# 82
# True
# 83
# True
# ...

# %%
# 07.21.2019
filename = digits_file.txt

with open(filename) as file_object:
    contents = file_oject.read()
    
print(contents)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-53b187750084> in <module>
#       1 # 07.21.2019
# ----> 2 filename = digits_file.txt
#       3
#       4 with open(filename) as file_object:
#       5     contents = file_oject.read()
#
# NameError: name 'digits_file' is not defined

# %%
# Writing a file:

filename = 'test.txt'

with open(filename, 'w') as file_object:
    file_object.write("I love programming.")
